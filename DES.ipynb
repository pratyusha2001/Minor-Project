# %%
pip install psutil
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install des
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install base64
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement base64 (from versions: none)
# ERROR: No matching distribution found for base64
#
# [notice] A new release of pip is available: 23.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import des as D
import base64
import os
import sys
import time
import psutil

# Switch case to encrypt and decrypt
print("1. Encrypt or 2. Decrypt")
a = int(input())
if a == 1:
    print("Virtual memory = {}".format(psutil.virtual_memory().percent))
    print("CPU usage = {}".format(psutil.cpu_percent()))
    start = time.time()
    key = D.DesKey(b"10293847")  # 100111010001001001010111
    key.is_single()
    
    # Change the file location
    img_path = r"C:\Users\Pratyusha Routh\Downloads\Assignments & Notes\Assignments & Notes\Fourth Year\Minor Project\DES\HorizonZero.png"
    
    with open(img_path, 'rb') as imgp:
        img = imgp.read()
    
    imgdes = key.encrypt(img, padding=True)
    
    with open('DES_enc.dat', 'wb') as imr:
        imr.write(imgdes)
    
    print("Encrypted file has been saved as 'DES_enc.dat' in your folder!")
    end = time.time()
    print("Time = {}".format(end - start))
    print("CPU usage = {}".format(psutil.cpu_percent()))
    print("Virtual memory = {}".format(psutil.virtual_memory().percent))
    process = psutil.Process(os.getpid())
    print("Memory required = {}".format(process.memory_info().rss))
    
elif a == 2:
    print("Virtual memory = {}".format(psutil.virtual_memory().percent))
    print("CPU usage = {}".format(psutil.cpu_percent()))
    start = time.time()
    key = D.DesKey(b"10293847")
    key.is_single()
    
    img_path = r"C:\Users\Pratyusha Routh\Downloads\Assignments & Notes\Assignments & Notes\Fourth Year\Minor Project\DES\DES_enc.dat"
    
    with open(img_path, 'rb') as imgp:
        img = imgp.read()
    
    imgdesdec = key.decrypt(img)
    
    with open('DES_dec.png', 'wb') as imr:
        imr.write(imgdesdec)
    
    print("Decrypted file has been saved as 'DES_dec.png' in your folder!")
    end = time.time()
    print("Time = {}".format(end - start))
    print("CPU usage = {}".format(psutil.cpu_percent()))
    print("Virtual memory = {}".format(psutil.virtual_memory().percent))
    process = psutil.Process(os.getpid())
    print("Memory required = {}".format(process.memory_info().rss))
# Out:
# 1. Encrypt or 2. Decrypt
# 2
# Virtual memory = 75.8
# CPU usage = 1.5
# Decrypted file has been saved as 'DES_dec.png' in your folder!
# Time = 4.7155725955963135
# CPU usage = 12.9
# Virtual memory = 75.6
# Memory required = 77488128

# %%
with open('DES_enc.dat', 'rb') as encrypted_file:
    encrypted_data = encrypted_file.read()

# Print the hexadecimal representation of the encrypted data
print(encrypted_data.hex())

# Alternatively, you can print it as base64-encoded data
import base64
print(base64.b64encode(encrypted_data).decode('utf-8'))
# Out:
# ...
# ...

# %%
pip install scikit-image
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install imagehash
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from skimage.metrics import structural_similarity as ssim
from math import log10, sqrt
import matplotlib.pyplot as plt
import numpy as np
import cv2
from collections import deque
from PIL import Image
import imagehash
import matplotlib.pyplot as plt
import hashlib
import collections
import ctypes
import array
import os
import sys
import time
from skimage.metrics import structural_similarity as ssim
from math import log10, sqrt
import matplotlib.pyplot as plt
import numpy as np
import cv2

def PSNR(original, compressed):
    mse = np.mean((original - compressed) ** 2)
    if(mse == 0):  # MSE is zero means no noise is present in the signal .
                  # Therefore PSNR have no importance.
        return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr

def mse(imageA, imageB):
    # the 'Mean Squared Error' between the two images is the
    # sum of the squared difference between the two images;
    # NOTE: the two images must have the same dimension
    err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
    err /= float(imageA.shape[0] * imageA.shape[1])
    
    # return the MSE, the lower the error, the more similar the two images are
    return err

original1 = cv2.imread("C:\\Users\\Pratyusha Routh\\Downloads\\Assignments & Notes\\Assignments & Notes\\Fourth Year\\Minor Project\\DES\\HorizonZero.png")
contrast1 = cv2.imread("C:\\Users\\Pratyusha Routh\\Downloads\\Assignments & Notes\\Assignments & Notes\\Fourth Year\\Minor Project\\DES\\DES_dec.png")

original = cv2.cvtColor(original1, cv2.COLOR_BGR2GRAY)
contrast = cv2.cvtColor(contrast1, cv2.COLOR_BGR2GRAY)

s = ssim(original, contrast)
m = mse(original, contrast)
p=PSNR(original, contrast)

print("SSIM:",s);
print("MSE:",m);
print("PSNR:",p);
# Out:
# SSIM: 1.0
# MSE: 0.0
# PSNR: 100
